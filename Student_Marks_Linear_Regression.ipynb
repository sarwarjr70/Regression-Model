# %% [markdown]
# <a href="https://colab.research.google.com/github/sarwarjr70/Regression-Model/blob/main/Student_Marks_Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dataset = pd.read_csv('/content/drive/MyDrive/GUB Doc/Student_Marks.csv')
dataset.head()
# Out:
#    number_courses  time_study   Marks
# 0               3       4.508  19.202
# 1               4       0.096   7.734
# 2               4       3.133  13.811
# 3               6       7.909  53.018
# 4               8       7.811  55.299

# %%
dataset.plot(x='time_study', y='Marks', style='o')
plt.title('Study_Time vs Marks')
plt.xlabel('Studied')
plt.ylabel('Marks')
plt.show()

# %%
X = dataset.iloc[:, :-1]. values
y = dataset.iloc[:, 1]. values

# %%
from sklearn.model_selection import train_test_split
X_train , X_test , y_train , y_test = train_test_split(X, y, test_size =0.2, random_state =0)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression ()
regressor.fit(X_train , y_train)
# Out:
# LinearRegression()

# %%
print(regressor.intercept_)
print(regressor.coef_)
# Out:
# 0.0
# [-3.36534635e-17  1.00000000e+00]

# %%
y_pred = regressor.predict(X_test)
df = pd.DataFrame ({'Actual': y_test , 'Predicted': y_pred})
df.head()
# Out:
#    Actual  Predicted
# 0   0.508      0.508
# 1   4.067      4.067
# 2   3.133      3.133
# 3   2.913      2.913
# 4   0.803      0.803

# %%
from sklearn import metrics
print('Mean Squared Error:', metrics.mean_squared_error(y_test , y_pred))
# Out:
# Mean Squared Error: 2.2803010541544874e-32

# %%
print('Accuracy:', metrics.r2_score(y_test , y_pred))
# Out:
# Accuracy: 1.0

# %%
plt.scatter(X_test[:, 1] , y_test , color = 'red')
plt.plot(X_test[:, 1] , y_pred , color = 'black', linewidth = 3)

plt.xticks(())
plt.yticks(())
plt.show()
