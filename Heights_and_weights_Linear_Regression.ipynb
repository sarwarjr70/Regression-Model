# %% [markdown]
# <a href="https://colab.research.google.com/github/sarwarjr70/Regression-Model/blob/main/Heights_and_weights_Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("/content/drive/MyDrive/GUB Doc/H&W_data.csv")
df.head()
# Out:
#    Height  Weight
# 0    1.47   52.21
# 1    1.50   53.12
# 2    1.52   54.48
# 3    1.55   55.84
# 4    1.57   57.20

# %%
df.plot(x='Height', y='Weight', style='o')
plt.title('Height vs Weight')
plt.xlabel('Height')
plt.ylabel('Weight')
plt.show()

# %%
X = df.iloc[:, :-1]. values
y = df.iloc[:, 1]. values

# %%
from sklearn.model_selection import train_test_split
X_train , X_test , y_train , y_test = train_test_split(X, y, test_size =0.2, random_state =0)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression ()
regressor.fit(X_train , y_train)
# Out:
# LinearRegression()

# %%
print(regressor.intercept_)
print(regressor.coef_)
# Out:
# -39.25676962267158
# [61.45820729]

# %%
y_pred = regressor.predict(X_test)
df = pd.DataFrame ({'Actual': y_test , 'Predicted': y_pred})
df.head()
# Out:
#    Actual  Predicted
# 0   53.12  52.930541
# 1   59.93  60.920108
# 2   63.11  63.993019

# %%
from sklearn import metrics
print('Mean Squared Error:', metrics.mean_squared_error(y_test , y_pred))
# Out:
# Mean Squared Error: 0.5986436208283817

# %%
print('Accuracy:', metrics.r2_score(y_test , y_pred))
# Out:
# Accuracy: 0.9655266437382162

# %%
plt.scatter(X_test, y_test, color='red')
plt.plot(X_test, y_pred, color='black', linewidth=3)

plt.xlabel('Height')
plt.ylabel('Predicted Height')
plt.title('Height vs Predicted Height')

plt.show()
